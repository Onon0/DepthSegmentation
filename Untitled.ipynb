# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms.functional as TF
from torchvision import datasets, models
from torch.optim import lr_scheduler
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
from torchvision.models.segmentation.deeplabv3 import DeepLabHead

# %%
import os
import datetime
from PIL import Image

# %%
from torchvision.utils import make_grid

# %%
import albumentations as A
from albumentations.pytorch import ToTensorV2
from tqdm import tqdm
import torch.optim as optim

# %%
import segmentation_models_pytorch as smp

# %%
from datasets import load_dataset

# %%
ds = load_dataset("sayakpaul/nyu_depth_v2", cache_dir = "./data")
# Out:
# Downloading builder script:   0%|          | 0.00/3.84k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/8.71k [00:00<?, ?B/s]
# Found cached dataset nyu_depth_v2 (D:/DLStudy/nyuDepth/data/sayakpaul___nyu_depth_v2/default/1.0.0/80157dc55fc37d154eb8157db00139028820c686cd2955a43a1d3850e315c383)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
def createDeepLabv3(outputchannels=1):
    model = models.segmentation.efficientnet_b5(
        weights=True, progress=True)
    # Added a Sigmoid activation after the last convolution layer
    model.classifier = DeepLabHead(2048, outputchannels)
    # Set the model in training mode
    model.train()
    return model

# %%
#model = model = smp.Unet('resnet152', encoder_weights='imagenet')
model = UNET()

# %%
def doubleConv(inChannel, outChannel, padding):
    conv = nn.Sequential(
            nn.Conv2d(inChannel, outChannel, 3,1,padding, bias=False),
            nn.BatchNorm2d(outChannel),
            nn.LeakyReLU(0.2)
    )
    return conv

class UNET(nn.Module):
    def __init__(self):
        super(UNET, self).__init__()
        modules = []
        #down sampling
        modules.append(doubleConv(3,64, 1))
        modules.append(doubleConv(64,64, 0))
        modules.append(nn.MaxPool2d(kernel_size=2, stride=2))
        modules.append(doubleConv(64,128,1))
        modules.append(doubleConv(128,128,0))
        modules.append(nn.MaxPool2d(kernel_size=2, stride=2))
        modules.append(doubleConv(128,256,1))
        modules.append(doubleConv(256,256,0))
        modules.append(nn.MaxPool2d(kernel_size=2, stride=2))
        modules.append(doubleConv(256,512,1))
        modules.append(doubleConv(512,512,0))
        modules.append(nn.MaxPool2d(kernel_size=2, stride=2))
        modules.append(doubleConv(512,1024,1))
        modules.append(doubleConv(1024,1024,0))
        
        #upsampling
        modules.append(nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2, bias=False))
        modules.append(doubleConv(512,512,0))
        modules.append(nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2, bias=False))
        modules.append(doubleConv(256,256,0))
        modules.append(nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2, bias=False))
        modules.append(doubleConv(128,128,0))
        modules.append(doubleConv(128,64,0))
        modules.append(doubleConv(64,64,0))
        modules.append(doubleConv(64,1,1))
        
        
        
        self.conv = nn.Sequential(*modules)
        
    def forward(self, x):
        return self.conv(x)

# %%
class NYUData(Dataset):
        def __init__(self):
            #ds = torch.tensor(load_dataset("sayakpaul/nyu_depth_v2", cache_dir = "./data"))
            
            self.data = ds
            self.rgb_trans = A.Compose([
                A.Resize(width = 224, height = 224),
                A.Normalize(
                       mean = [0.0, 0.0, 0.0],
                        std = [1.0, 1.0, 1.0],
                        max_pixel_value=255.0
                    ),
                ToTensorV2()
            ])
            
            self.dep_trans = A.Compose([
                A.Resize(width = 62, height = 62),
                A.Normalize(
                       mean = 0.0,
                        std = 1.0,
                        max_pixel_value=255.0
                    ),
                ToTensorV2()
            ])
        def __getitem__(self, index):
            image = np.array(self.data['train'][index]['image'])
            image = self.rgb_trans(image = image)["image"]
            depth = np.array(self.data['train'][index]['depth_map'])
            depth = self.dep_trans(image = depth)["image"]
            return  image , depth 
        def __len__(self):
            return len(self.data['train'])

# %%
train_size = 10000
dataset = NYUData()
train_dataset = torch.utils.data.Subset(dataset, range(train_size))
val_dataset = torch.utils.data.Subset(dataset, range(train_size, train_size + len(dataset) - 1))
#train_dataset = torch.utils.data.Subset(tokenized_datasets, range(train_size))
train_loader = DataLoader(dataset=train_dataset, batch_size=32)
val_loader = DataLoader(dataset=val_dataset, batch_size=32)

# %%
for batch in train_loader:
    image, depth = batch
    r = model(image)
    break

# %%
r.shape
# Out:
# torch.Size([32, 1, 62, 62])

# %%
LEARNING_RATE = 1e-4
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
BATH_SIZE = 4
NUM_EPOCHS = 100
NUM_WORKERS = 2
IMAGE_HEIGHT = 224
IMAGE_WIDTH = 224
PIN_MEMORY = True
LOAD_MODEL = True

# %%
class RMSELoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.mse = nn.MSELoss()
        
    def forward(self,yhat,y):
        return torch.sqrt(self.mse(yhat,y))

# %%
model.load_state_dict(torch.load("D:\\DLStudy\\nyuDepth\\model\\2023-09-19_23-48_5_checkpoint.pth"))
# Out:
# <All keys matched successfully>

# %%
i = 0
for param in model.parameters():
    i= i + 1
    if(i == 300):
        break
    param.requires_grad = False
print(i)
# Out:
# 300

# %%
for param in model.parameters():
    param.requires_grad =True

# %%
#model =UNET().to(DEVICE)
#load from checkpoint
#model.load_state_dict(torch.load("D:\\DLStudy\\nyuDepth\\model\\2023-09-03_14-57_3_checkpoint.pth"))

model.to(DEVICE)

optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
scaler = torch.cuda.amp.GradScaler()

# %%
#loss_fn = nn.MSELoss()
loss_fn = nn.L1Loss()

# %%
def Average(lst):
    return sum(lst) / len(lst)

# %%
def train(loader, model, optimizer, loss_fn, scaler):
    loop = tqdm(loader)
    history = []
    for batch_idx, (data, targets) in enumerate(loop):
        data = data.to(device = DEVICE)
        targets = targets.to(device = DEVICE)
        
        #forward
        with torch.cuda.amp.autocast():
            predictions = model(data)
            #loss = loss_fn(predictions['out'], targets)
            loss = loss_fn(predictions, targets)
            history.append(loss)
        optimizer.zero_grad()
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        loop.set_postfix(loss = Average(history))

# %%
def save_result(epoch):
    i = 0
    for batch in val_loader:
        i = i+ 1
        if(i==100): 
            image, depth = batch
            r = model(image.cuda())
            f, axarr = plt.subplots(1,4)
            for i in range(4):
                #axarr[i].imshow(r['out'][i][0].cpu().detach().numpy())
                axarr[i].imshow(r[i][0].cpu().detach().numpy())
            PATH = os.path.join(os.getcwd(), "result", datetime.datetime.now().strftime("%Y-%m-%d_%H-%M")+"_" +str(epoch) + ".jpg")
            plt.savefig(PATH)
            break

# %%
save_result(0)

# %%
def show_depths(images, nmax=64):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(images.detach()[:nmax], nrow=8)[2])
    
def show_images(images, nmax=64):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(images.detach()[:nmax], nrow=8).permute(1, 2, 0))

def show_batch(dl, nmax=64):
    for images, depth in dl:
        show_images(image, nmax)
        show_depths(depth, nmax)
        break

# %%
show_batch(train_loader,16)

# %%
i = 0
for batch in val_loader:
    i = i+ 1
    if(i==100):
        image, depth = batch
        
        f, axarr = plt.subplots(1,4)
        axarr.set_xticks([]); axarr.set_yticks([])
        for i in range(4):
            axarr[i].imshow(depth[i][0])
        PATH = os.path.join(os.getcwd(), "result", datetime.datetime.now().strftime("%Y-%m-%d_%H-%M") + ".jpg")
        #plt.savefig(PATH)
        break
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2644\444293165.py in <module>
#       6
#       7         f, axarr = plt.subplots(1,4)
# ----> 8         axarr.set_xticks([]); axarr.set_yticks([])
#       9         for i in range(4):
#      10             axarr[i].imshow(depth[i][0])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'set_xticks'

# %%
for epoch in range(NUM_EPOCHS):
    train(train_loader, model, optimizer, loss_fn, scaler)
    PATH = os.path.join(os.getcwd(), "model", datetime.datetime.now().strftime("%Y-%m-%d_%H-%M")+"_" +str(epoch) + "_checkpoint.pth")
    torch.save(model.state_dict(), PATH)
    save_result(epoch)
# Out:
# 100%|██████████████████| 313/313 [09:03<00:00,  1.74s/it, loss=tensor(0.0499, device='cuda:0', grad_fn=<DivBackward0>)]
#   7%|█▎                 | 22/313 [00:43<09:39,  1.99s/it, loss=tensor(0.0342, device='cuda:0', grad_fn=<DivBackward0>)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2644\2547577677.py in <module>
#       1 for epoch in range(NUM_EPOCHS):
# ----> 2     train(train_loader, model, optimizer, loss_fn, scaler)
#       3     PATH = os.path.join(os.getcwd(), "model", datetime.datetime.now().strftime("%Y-%m-%d_%H-%M")+"_" +str(epoch) + "_checkpoint.pth")
#       4     torch.save(model.state_dict(), PATH)
#       5     save_result(epoch)
#
# ~\AppData\Local\Temp\ipykernel_2644\74715905.py in train(loader, model, optimizer, loss_fn, scaler)
#       2     loop = tqdm(loader)
#       3     history = []
# ----> 4     for batch_idx, (data, targets) in enumerate(loop):
#       5         data = data.to(device = DEVICE)
#       6         targets = targets.to(device = DEVICE)
#
# d:\python\python37\lib\site-packages\tqdm\std.py in __iter__(self)
#    1176
#    1177         try:
# -> 1178             for obj in iterable:
#    1179                 yield obj
#    1180                 # Update and possibly print the progressbar.
#
# d:\python\python37\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     626                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627                 self._reset()  # type: ignore[call-arg]
# --> 628             data = self._next_data()
#     629             self._num_yielded += 1
#     630             if self._dataset_kind == _DatasetKind.Iterable and \
#
# d:\python\python37\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     669     def _next_data(self):
#     670         index = self._next_index()  # may raise StopIteration
# --> 671         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672         if self._pin_memory:
#     673             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# d:\python\python37\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      56                 data = self.dataset.__getitems__(possibly_batched_index)
#      57             else:
# ---> 58                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      59         else:
#      60             data = self.dataset[possibly_batched_index]
#
# d:\python\python37\lib\site-packages\torch\utils\data\_utils\fetch.py in <listcomp>(.0)
#      56                 data = self.dataset.__getitems__(possibly_batched_index)
#      57             else:
# ---> 58                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      59         else:
#      60             data = self.dataset[possibly_batched_index]
#
# d:\python\python37\lib\site-packages\torch\utils\data\dataset.py in __getitem__(self, idx)
#     293         if isinstance(idx, list):
#     294             return self.dataset[[self.indices[i] for i in idx]]
# --> 295         return self.dataset[self.indices[idx]]
#     296
#     297     def __len__(self):
#
# ~\AppData\Local\Temp\ipykernel_2644\3128158033.py in __getitem__(self, index)
#      24             ])
#      25         def __getitem__(self, index):
# ---> 26             image = np.array(self.data['train'][index]['image'])
#      27             image = self.rgb_trans(image = image)["image"]
#      28             depth = np.array(self.data['train'][index]['depth_map'])
#
# KeyboardInterrupt:
