# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms.functional as F
from torchvision import datasets, models
from torch.optim import lr_scheduler
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
from torchvision.models.segmentation.deeplabv3 import DeepLabHead

# %%
from skimage.metrics import structural_similarity as ssim

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
DEVICE
# Out:
# 'cuda'

# %%
import os
import datetime
import random
from PIL import Image

# %%
from torchvision.utils import make_grid

# %%
import albumentations as A
from albumentations.pytorch import ToTensorV2
from tqdm import tqdm
import torch.optim as optim

# %%
import segmentation_models_pytorch as smp

# %%
from datasets import load_dataset

# %%
ds = load_dataset("sayakpaul/nyu_depth_v2", cache_dir = "./data")
# Out:
# Found cached dataset nyu_depth_v2 (G:/DepthSegmentation/data/sayakpaul___nyu_depth_v2/default/1.0.0/80157dc55fc37d154eb8157db00139028820c686cd2955a43a1d3850e315c383)
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [10:31<00:00, 315.57s/it]

# %%
def createModel(outputchannels=1):
    model = models.densenet169(
        weights=True, progress=True)
    # Added a Sigmoid activation after the last convolution layer
    model.classifier = DeepLabHead(2048, outputchannels)
    # Set the model in training mode
    model.train()
    return model

# %%
class DDN(nn.Module):
    def __init__(self):
        super(DDN, self).__init__()
        
        self.encoder = models.densenet169(weights=True, progress=True)
        self.encoder = nn.Sequential(*list(self.encoder.children())[:-1])
        self.decoder = nn.Sequential(
            nn.Upsample(scale_factor=2, mode='bilinear', align_corners=False),
            nn.ConvTranspose2d(1664, 16,kernel_size=3, stride=1, padding=1,bias=False),
            nn.ConvTranspose2d(16, 8, kernel_size=2, stride=2, bias=False),
            nn.ConvTranspose2d(8, 4, kernel_size=2, stride=2, bias=False),
            nn.ConvTranspose2d(4, 2, kernel_size=2, stride=2, bias=False),
            nn.ConvTranspose2d(2, 1, kernel_size=2, stride=2, bias=False),
            
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# %%
model = DDN()

# %%
for batch in train_loader:
    image, depth = batch
    r = model(image)
    break

# %%
r.shape
# Out:
# torch.Size([32, 1, 224, 224])

# %%
#model = model = smp.Unet('resnet152', encoder_weights='imagenet')
#model = UNET()

# %%
def doubleConv(inChannel, outChannel, padding):
    conv = nn.Sequential(
            nn.Conv2d(inChannel, outChannel, 3,1,padding, bias=False),
            nn.BatchNorm2d(outChannel),
            nn.LeakyReLU(0.2)
    )
    return conv

class UNET(nn.Module):
    def __init__(self):
        super(UNET, self).__init__()
        modules = []
        #down sampling
        modules.append(doubleConv(3,64, 1))
        modules.append(doubleConv(64,64, 0))
        modules.append(nn.MaxPool2d(kernel_size=2, stride=2))
        modules.append(doubleConv(64,128,1))
        modules.append(doubleConv(128,128,0))
        modules.append(nn.MaxPool2d(kernel_size=2, stride=2))
        modules.append(doubleConv(128,256,1))
        modules.append(doubleConv(256,256,0))
        modules.append(nn.MaxPool2d(kernel_size=2, stride=2))
        modules.append(doubleConv(256,512,1))
        modules.append(doubleConv(512,512,0))
        modules.append(nn.MaxPool2d(kernel_size=2, stride=2))
        modules.append(doubleConv(512,1024,1))
        modules.append(doubleConv(1024,1024,0))
        
        #upsampling
        modules.append(nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2, bias=False))
        modules.append(doubleConv(512,512,0))
        modules.append(nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2, bias=False))
        modules.append(doubleConv(256,256,0))
        modules.append(nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2, bias=False))
        modules.append(doubleConv(128,128,0))
        modules.append(doubleConv(128,64,0))
        modules.append(doubleConv(64,64,0))
        modules.append(doubleConv(64,1,1))
        
        
        
        self.conv = nn.Sequential(*modules)
        
    def forward(self, x):
        return self.conv(x)

# %%
class NYUData(Dataset):
        def __init__(self):
            #ds = torch.tensor(load_dataset("sayakpaul/nyu_depth_v2", cache_dir = "./data"))
            
            self.data = ds
            
        def __getitem__(self, index):
            flip = random.randint(0,1)
            rot = random.randint(-45,45)
            
            self.rgb_trans = A.Compose([
                A.Resize(width = 224, height = 224),
                A.Normalize(
                       mean = [0.0, 0.0, 0.0],
                        std = [1.0, 1.0, 1.0],
                        max_pixel_value=255.0
                    ),
                A.HorizontalFlip(p=flip),
               
                A.RandomBrightnessContrast(),
                
                ToTensorV2()
            ])
            self.dep_trans = A.Compose([
                A.Resize(width = 224, height = 224),
                A.Normalize(
                       mean = 0.0,
                        std = 1.0,
                        max_pixel_value=255.0
                    ),
                A.HorizontalFlip(p=flip),
                
                ToTensorV2()
            ])
            
            image = F.rotate(img = self.data['train'][index]['image'], interpolation = transforms.InterpolationMode.BILINEAR , angle = rot, expand= False)
            image = F.center_crop(img = image, output_size = [224])
            image = np.array(image)
            image = self.rgb_trans(image = image)["image"]
            
            depth = TF.rotate(img = self.data['train'][index]['depth_map'], interpolation = transforms.InterpolationMode.BILINEAR, angle = rot, expand= False)
            depth = TF.center_crop(img = depth, output_size = [224])
            depth = np.array(depth)
            
            depth = self.dep_trans(image = depth)["image"]
            return  image , depth 
        def __len__(self):
            return len(self.data['train'])

# %%
train_size = 20000
dataset = NYUData()
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, len(dataset) - train_size])
#val_dataset = torch.utils.data.Subset(dataset, range(train_size, train_size + len(dataset) - 1))
train_loader = DataLoader(dataset=train_dataset, batch_size=8)
val_loader = DataLoader(dataset=val_dataset, batch_size=8)

# %%
show_batch(train_loader,8)

# %%
def show_depths(images, nmax=64):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(images.detach()[:nmax], nrow=8)[0])
    
def show_images(images, nmax=64):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(images.detach()[:nmax], nrow=8).permute(1, 2, 0))

def show_batch(dl, nmax=64):
    for images, depth in dl:
        show_images(images, nmax)
        show_depths(depth, nmax)
        break

# %%
LEARNING_RATE = 1e-4
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
BATH_SIZE = 4
NUM_EPOCHS = 100
NUM_WORKERS = 2
IMAGE_HEIGHT = 224
IMAGE_WIDTH = 224
PIN_MEMORY = True
LOAD_MODEL = True

# %%
class RMSELoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.mse = nn.MSELoss()
        
    def forward(self,yhat,y):
        return torch.sqrt(self.mse(yhat,y))

# %%
model.load_state_dict(torch.load("D:\\DLStudy\\nyuDepth\\model\\2023-09-19_23-48_5_checkpoint.pth"))
# Out:
# <All keys matched successfully>

# %%
i = 0
for param in model.parameters():
    i= i + 1
    if(i == 300):
        break
    param.requires_grad = False
print(i)
# Out:
# 300

# %%
for param in model.parameters():
    param.requires_grad =True

# %%
#model =UNET().to(DEVICE)
#load from checkpoint
#model.load_state_dict(torch.load("D:\\DLStudy\\nyuDepth\\model\\2023-09-03_14-57_3_checkpoint.pth"))

model.to(DEVICE)

optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
scaler = torch.cuda.amp.GradScaler()

# %%
class SSIM(torch.nn.Module):
    def __init__(self):
        super(SSIM, self).__init__()
        

    def forward(self, x, y):
        Mx = torch.mean(x)
        My = torch.mean(y)
        xy = x * y;
        Vx = torch.mean((x - Mx) ** 2)
        Vy = torch.mean((y - My) ** 2)
        Vxy = torch.mean(xy) - Mx - My
        c1 = 0.0001 
        c2 = 0.0009
        ssim = (2 * Mx * My + c1) * (2 * Vxy + c2) / (Mx**2 + My**2 + c1) * (Vx + Vy + c2)
        return (1-ssim)/2

# %%
p = torch.tensor([1,2,3,4], dtype = torch.float)
q = torch.tensor([1,6,3,4], dtype = torch.float)
s = SSIM()
q = s(p,q)
q
# Out:
# tensor(-14.4035)

# %%
class Loss_Function(nn.Module):
    def __init__(self):
        super().__init__()
        self.L1 = nn.L1Loss()
        self.ssim = SSIM()
    def forward(self,yhat,y):
        loss = self.L1(yhat, y)
        loss1 = self.ssim(yhat, y)
        return loss + loss1

# %%
#loss_fn = nn.MSELoss()
#loss_fn = nn.L1Loss()
loss_fn = Loss_Function()

# %%
def Average(lst):
    return sum(lst) / len(lst)

# %%
def train(loader, model, optimizer, loss_fn, scaler):
    loop = tqdm(loader)
    history = []
    for batch_idx, (data, targets) in enumerate(loop):
        data = data.to(device = DEVICE)
        targets = targets.to(device = DEVICE)
        
        #forward
        with torch.cuda.amp.autocast():
            predictions = model(data)
            #loss = loss_fn(predictions['out'], targets)
            loss = loss_fn(predictions, targets)
            history.append(loss)
        optimizer.zero_grad()
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        loop.set_postfix(loss = Average(history))
    return Average(history)

# %%
def save_result(epoch):
    i = 0
    for batch in val_loader:
        i = i+ 1
        if(i==100): 
            image, depth = batch
            r = model(image.cuda())
            f, axarr = plt.subplots(2,4)
            for ax in axarr.flatten():
                ax.set_xticks([])
                ax.set_yticks([])
            for i in range(4):
                axarr[0][i].imshow(depth[i].detach().permute(1,2,0))
            for i in range(4):
                #axarr[i].imshow(r['out'][i][0].cpu().detach().numpy())
                axarr[1][i].imshow(r[i][0].cpu().detach().numpy())
            PATH = os.path.join(os.getcwd(), "result", datetime.datetime.now().strftime("%Y-%m-%d_%H-%M")+"_" +str(epoch) + ".jpg")
            plt.savefig(PATH)
            break

# %%
result = []
for epoch in range(NUM_EPOCHS):
    l = train(train_loader, model, optimizer, loss_fn, scaler)
    result.append(l)
    PATH = os.path.join(os.getcwd(), "model", datetime.datetime.now().strftime("%Y-%m-%d_%H-%M")+"_" +str(epoch) + "_checkpoint.pth")
    torch.save(model.state_dict(), PATH)
    save_result(epoch)
# Out:
# 100%|████████████████| 2500/2500 [39:00<00:00,  1.07it/s, loss=tensor(0.5099, device='cuda:0', grad_fn=<DivBackward0>)]
# 100%|████████████████| 2500/2500 [37:35<00:00,  1.11it/s, loss=tensor(0.5035, device='cuda:0', grad_fn=<DivBackward0>)]
#   7%|█                | 163/2500 [02:29<35:40,  1.09it/s, loss=tensor(0.5031, device='cuda:0', grad_fn=<DivBackward0>)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11372\4049474472.py in <module>
#       1 result = []
#       2 for epoch in range(NUM_EPOCHS):
# ----> 3     l = train(train_loader, model, optimizer, loss_fn, scaler)
#       4     result.append(l)
#       5     PATH = os.path.join(os.getcwd(), "model", datetime.datetime.now().strftime("%Y-%m-%d_%H-%M")+"_" +str(epoch) + "_checkpoint.pth")
#
# ~\AppData\Local\Temp\ipykernel_11372\735710655.py in train(loader, model, optimizer, loss_fn, scaler)
#       2     loop = tqdm(loader)
#       3     history = []
# ----> 4     for batch_idx, (data, targets) in enumerate(loop):
#       5         data = data.to(device = DEVICE)
#       6         targets = targets.to(device = DEVICE)
#
# f:\python\python37\lib\site-packages\tqdm\std.py in __iter__(self)
#    1180
#    1181         try:
# -> 1182             for obj in iterable:
#    1183                 yield obj
#    1184                 # Update and possibly print the progressbar.
#
# f:\python\python37\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     626                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627                 self._reset()  # type: ignore[call-arg]
# --> 628             data = self._next_data()
#     629             self._num_yielded += 1
#     630             if self._dataset_kind == _DatasetKind.Iterable and \
#
# f:\python\python37\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     669     def _next_data(self):
#     670         index = self._next_index()  # may raise StopIteration
# --> 671         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672         if self._pin_memory:
#     673             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# f:\python\python37\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      56                 data = self.dataset.__getitems__(possibly_batched_index)
#      57             else:
# ---> 58                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      59         else:
#      60             data = self.dataset[possibly_batched_index]
#
# f:\python\python37\lib\site-packages\torch\utils\data\_utils\fetch.py in <listcomp>(.0)
#      56                 data = self.dataset.__getitems__(possibly_batched_index)
#      57             else:
# ---> 58                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      59         else:
#      60             data = self.dataset[possibly_batched_index]
#
# f:\python\python37\lib\site-packages\torch\utils\data\dataset.py in __getitem__(self, idx)
#     293         if isinstance(idx, list):
#     294             return self.dataset[[self.indices[i] for i in idx]]
# --> 295         return self.dataset[self.indices[idx]]
#     296
#     297     def __len__(self):
#
# ~\AppData\Local\Temp\ipykernel_11372\3796719813.py in __getitem__(self, index)
#      39             image = self.rgb_trans(image = image)["image"]
#      40
# ---> 41             depth = TF.rotate(img = self.data['train'][index]['depth_map'], interpolation = transforms.InterpolationMode.BILINEAR, angle = rot, expand= False)
#      42             depth = TF.center_crop(img = depth, output_size = [224])
#      43             depth = np.array(depth)
#
# f:\python\python37\lib\site-packages\torchvision\transforms\functional.py in rotate(img, angle, interpolation, expand, center, fill)
#    1105     if not isinstance(img, torch.Tensor):
#    1106         pil_interpolation = pil_modes_mapping[interpolation]
# -> 1107         return F_pil.rotate(img, angle=angle, interpolation=pil_interpolation, expand=expand, center=center, fill=fill)
#    1108
#    1109     center_f = [0.0, 0.0]
#
# f:\python\python37\lib\site-packages\torchvision\transforms\functional_pil.py in rotate(img, angle, interpolation, expand, center, fill)
#     312
#     313     opts = _parse_fill(fill, img)
# --> 314     return img.rotate(angle, interpolation, expand, center, **opts)
#     315
#     316
#
# f:\python\python37\lib\site-packages\PIL\Image.py in rotate(self, angle, resample, expand, center, translate, fillcolor)
#    2342
#    2343         return self.transform(
# -> 2344             (w, h), Transform.AFFINE, matrix, resample, fillcolor=fillcolor
#    2345         )
#    2346
#
# f:\python\python37\lib\site-packages\PIL\Image.py in transform(self, size, method, data, resample, fill, fillcolor)
#    2701             raise ValueError(msg)
#    2702
# -> 2703         im = new(self.mode, size, fillcolor)
#    2704         if self.mode == "P" and self.palette:
#    2705             im.palette = self.palette.copy()
#
# f:\python\python37\lib\site-packages\PIL\Image.py in new(mode, size, color)
#    2931         im.palette = ImagePalette.ImagePalette()
#    2932         color = im.palette.getcolor(color)
# -> 2933     return im._new(core.fill(mode, size, color))
#    2934
#    2935
#
# KeyboardInterrupt:

# %%
save_result(0)
